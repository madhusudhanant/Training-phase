# %% [markdown]
# #Project 1: Personal Budget Tracker

# %% [markdown]
# 1. Open a Python editor.
# 2. Create a dictionary to store income sources and amounts (e.g., "salary", "freelance").
# 3. Create a second dictionary for expense categories and amounts (e.g., "rent", "food").
# 4. Write a function to calculate total income by summing dictionary values.
# 5. Write a function to calculate total expenses similarly.
# 6. Compute the balance by subtracting total expenses from total income.
# 7. Print a formatted summary showing all three values.
# 8. **🔹 Expected Output:** Printed summary of total income, expenses, and balance (e.g., "Income: 3000, Expenses: 2000, Balance: 1000").

# %%
income_sourse={"salary":50000,"freelance":18000}
expense_cate={"rent":5000,"food":4000,"cosmetics":5000,"others":6000}

# %%
def tot_inc():
    return sum(income_sourse.values())

# %%
def tot_exp():
    return sum(expense_cate.values())

# %%
balance = tot_inc() - tot_exp()
print(f"Total Income:{tot_inc()} Total Expense:{tot_exp()} Balance:{balance}")
# Out:
# Total Income:68000 Total Expense:20000 Balance:48000

# %% [markdown]
# #Project 2: Student Grade Analyzer

# %% [markdown]
# 1. Open a Python editor.
# 2. Initialize an empty list to store student grades.
# 3. Use a loop to prompt the user for 5 student names and their grades (0-100).
# 4. Store each as a tuple (name, grade) in the list.
# 5. Define a function to calculate the average grade from the list.
# 6. Define a function to count how many students scored above 60 (passing).
# 7. Print the average grade and the number of passing students.
# 8. **🔹 Expected Output:** Printed average grade (e.g., "Average: 75.2") and pass/fail count (e.g., "Passing: 4").

# %%
'''from statistics import mean
students = []'''
# Out:
# 'from statistics import mean\nstudents = []'

# %%
'''for i in range(5):
  name = input(f"Enter the student{i+1} Name: ")
  grade = int(input(f"Enter student{i+1} grade(o-100):"))
  students.append((name,grade))'''
# Out:
# 'for i in range(5):\n  name = input(f"Enter the student{i+1} Name: ")\n  grade = int(input(f"Enter student{i+1} grade(o-100):"))\n  students.append((name,grade))'

# %%
'''def cal_average():
    return mean([grades for _ , grades in students])'''
# Out:
# 'def cal_average():\n    return mean([grades for _ , grades in students])'

# %%
'''def pass_students():
    return sum([1 for _ , grade in students if grade > 60])'''
# Out:
# 'def pass_students():\n    return sum([1 for _ , grade in students if grade > 60])'

# %%
'''average = cal_average()
passed_students = pass_students()'''
# Out:
# 'average = cal_average()\npassed_students = pass_students()'

# %% [markdown]
# #TASK 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[["Age","Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
survival_rates = df.groupby("Pclass")["Survived"].mean()
print(f"Survival Rates:{survival_rates}")
# Out:
# Survival Rates:Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,5))
sns.barplot(x=survival_rates.index, y=survival_rates.values, hue=survival_rates.index , palette="coolwarm")
plt.xlabel("Passanger Class")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by passanger Class")
plt.ylim(0,1)
plt.show()

# %% [markdown]
# #Task 4

# %%
import hashlib

# %%
message = input("Enter the short message: ")
# Out:
# Enter the short message: hello

# %%
with open("message.txt", "w") as file:
    file.write(message)

# %%
with open("message.txt", "r") as file:
    content = file.read()

# %%
hashed_content = hashlib.sha256(content.encode()).hexdigest()

# %%
with open("encrypted.txt", "w") as file:
    file.write(hashed_content)

# %%
print(f"SHA256 Hash: {hashed_content}")
# Out:
# SHA256 Hash: 2cf24dba5fb0a30e26e83b2ac5b9e29e1b161e5c1fa7425e73043362938b9824

# %% [markdown]
# #TASK 5

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df[['price','area']].describe()
# Out:
#               price          area
# count  5.450000e+02    545.000000
# mean   4.766729e+06   5150.541284
# std    1.870440e+06   2170.141023
# min    1.750000e+06   1650.000000
# 25%    3.430000e+06   3600.000000
# 50%    4.340000e+06   4600.000000
# 75%    5.740000e+06   6360.000000
# max    1.330000e+07  16200.000000

# %%
df["price_per_area"]=df["price"]/df["area"]
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    price_per_area
# 0     1792.452830
# 1     1367.187500
# 2     1229.919679
# ...

# %%
plt.scatter(df["price"],df["area"],alpha=0.6)
plt.xlabel('Area')
plt.ylabel('Price')
plt.title("Price vs Area")
# Out:
# Text(0.5, 1.0, 'Price vs Area')

# %% [markdown]
# #task 6

# %%
import threading
import logging
import pandas as pd

# %%
logging.basicConfig(filename="processing.log", level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

# %%
def process_file(file_name, column_name):
    logging.info(f"Started processing {file_name}")
    try:
        df = pd.read_csv(file_name)
        mean_value = df[column_name].mean()
        logging.info(f"Finished processing {file_name}) - Mean: {mean_value}")
        print(f"Mean f {column_name} in {file_name}): {mean_value:.2f}")
    except Exception as e:
        logging.error(f"Error processing {file_name}: {e}")

# %%
file1, file2 = "/content/Titanic-Dataset.csv","/content/Titanic Dataset.csv"
column = "SibSp"

# %%
thread1 = threading.Thread(target=process_file, args=(file1, column))
thread2 = threading.Thread(target=process_file, args=(file2, column))

# %%
thread1.start()
thread2.start()

# %%
thread1.join()
thread2.join()
# Out:
# ERROR:root:Error processing /content/Titanic Dataset.csv: 'SibSp'
# Mean f SibSp in /content/Titanic-Dataset.csv): 0.52

# %% [markdown]
# #Task 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %%
class DatasetStats:
    mean: float
    min: float
    max: float

    def
# Out:
#   File "<ipython-input-138-cad85a3662f8>", line 6
#     def
#         ^
# SyntaxError: invalid syntax
